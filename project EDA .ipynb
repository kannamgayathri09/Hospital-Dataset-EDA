# %%
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\GAYATHRI GOUTHAMI\OneDrive\Desktop\\Hospital_Dataset (1).csv")
df
# Out:
#      Patient_ID  Gender  Age       City        Department Doctor_Name  \
# 0       PAT1001    Male   40  Bangalore  General Medicine    Dr. Khan
# 1       PAT1002    Male   43  Hyderabad          Oncology   Dr. Patel
# 2       PAT1003  Female   20       Pune       Orthopedics   Dr. Reddy
# 3       PAT1004  Female   81      Delhi       Orthopedics   Dr. Patel
# 4       PAT1005    Male   79       Pune       Orthopedics    Dr. Khan
# ...         ...     ...  ...        ...               ...         ...
# 1495    PAT2496    Male   71      Delhi        Pediatrics   Dr. Patel
# 1496    PAT2497  Female   20  Hyderabad  General Medicine   Dr. Patel
# 1497    PAT2498  Female   55       Pune          Oncology  Dr. Sharma
# 1498    PAT2499    Male   32  Ahmedabad       Orthopedics    Dr. Iyer
# 1499    PAT2500  Female   25  Bangalore        Cardiology  Dr. Sharma
#
#      Admission_Date Discharge_Date  Length_of_Stay      Diagnosis  \
# ...

# %%
df.head(5)
# Out:
#   Patient_ID  Gender  Age       City        Department Doctor_Name  \
# 0    PAT1001    Male   40  Bangalore  General Medicine    Dr. Khan
# 1    PAT1002    Male   43  Hyderabad          Oncology   Dr. Patel
# 2    PAT1003  Female   20       Pune       Orthopedics   Dr. Reddy
# 3    PAT1004  Female   81      Delhi       Orthopedics   Dr. Patel
# 4    PAT1005    Male   79       Pune       Orthopedics    Dr. Khan
#
#   Admission_Date Discharge_Date  Length_of_Stay      Diagnosis  \
# 0     2023-01-26     2023-02-03               8  Heart Disease
# 1     2022-04-07     2022-04-20              13      Infection
# 2     2024-05-16     2024-05-24               8  Heart Disease
# 3     2023-08-01     2023-08-10               9  Heart Disease
# 4     2022-12-20     2022-12-26               6      Infection
#
#    Treatment_Cost  Insurance_Coverage_%  Hospital_Revenue Payment_Mode
# 0       190406.00                 73.99          49524.60         Cash
# ...

# %% [markdown]
# ## DATA EXPLORATION

# %%
df.shape
# Out:
# (1500, 14)

# %%
df.dtypes
# Out:
# Patient_ID               object
# Gender                   object
# Age                       int64
# City                     object
# Department               object
# Doctor_Name              object
# Admission_Date           object
# Discharge_Date           object
# Length_of_Stay            int64
# Diagnosis                object
# Treatment_Cost          float64
# Insurance_Coverage_%    float64
# Hospital_Revenue        float64
# Payment_Mode             object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Patient_ID            1500 non-null   object
#  1   Gender                1500 non-null   object
#  2   Age                   1500 non-null   int64
#  3   City                  1500 non-null   object
#  4   Department            1500 non-null   object
#  5   Doctor_Name           1500 non-null   object
#  6   Admission_Date        1500 non-null   object
#  7   Discharge_Date        1500 non-null   object
#  8   Length_of_Stay        1500 non-null   int64
#  9   Diagnosis             1500 non-null   object
#  10  Treatment_Cost        1500 non-null   float64
#  11  Insurance_Coverage_%  1500 non-null   float64
#  12  Hospital_Revenue      1500 non-null   float64
#  13  Payment_Mode          1500 non-null   object
# dtypes: float64(3), int64(2), object(9)
# ...

# %%
df.describe()
# Out:
#                Age  Length_of_Stay  Treatment_Cost  Insurance_Coverage_%  \
# count  1500.000000     1500.000000     1500.000000           1500.000000
# mean     42.410000        8.036000   103736.145067             39.663380
# std      24.398062        4.369069    56956.041043             23.291962
# min       1.000000        1.000000     5005.160000              0.020000
# 25%      22.000000        4.000000    52944.257500             19.050000
# 50%      41.000000        8.000000   105321.170000             39.650000
# 75%      63.000000       12.000000   153574.550000             59.642500
# max      85.000000       15.000000   199748.110000             79.980000
#
#        Hospital_Revenue
# count       1500.000000
# mean       62531.076873
# std        44127.520547
# min         1082.620000
# 25%        27807.285000
# 50%        52238.990000
# 75%        89731.912500
# max       193634.530000

# %% [markdown]
# ## DATA CLEANING

# %%
print(df.isnull().sum())
# Out:
# Patient_ID              0
# Gender                  0
# Age                     0
# City                    0
# Department              0
# Doctor_Name             0
# Admission_Date          0
# Discharge_Date          0
# Length_of_Stay          0
# Diagnosis               0
# Treatment_Cost          0
# Insurance_Coverage_%    0
# Hospital_Revenue        0
# Payment_Mode            0
# dtype: int64

# %% [markdown]
# ## DUPLICATED VALUES

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## OUTLIERS

# %%
import numpy as np

# %%
a=df.select_dtypes(include=np.number)

# %%
for i in a:
    q1=a[i].quantile(0.25)
    q2=a[i].quantile(0.5)
    q3=a[i].quantile(0.75)

# %%
IQR=q3-q1

# %%
uw=q3+1.5*IQR
lw=q1-1.5*IQR

# %%
outliers=((a[i]>uw)&(a[i]<lw))

# %%
outliers.sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## DATA ANALYSIS

# %%
a=pd.DataFrame(df.groupby("Diagnosis")["Treatment_Cost"].mean().sort_values(ascending=False))
a
# Out:
#                Treatment_Cost
# Diagnosis
# Heart Disease   106653.276809
# Migraine        105583.566094
# Fracture        104240.342551
# Diabetes        103942.477068
# Cancer          103439.885212
# Infection        99048.972577

# %% [markdown]
# ## The average treatment cost is high for the heart disease.

# %%
b=pd.DataFrame(df.groupby("Department")["Treatment_Cost"].mean().sort_values(ascending=False))
b
# Out:
#                   Treatment_Cost
# Department
# Neurology          111093.769416
# Oncology           104999.932841
# Cardiology         104677.374911
# Orthopedics        102892.543727
# Pediatrics         101597.784132
# General Medicine    96755.626033

# %% [markdown]
# ## In the neurology department the average treatement cost is high

# %%
df["Patient_ID"].count()
# Out:
# np.int64(1500)

# %% [markdown]
# ## There are 1500 patients in this hospital

# %%
print(df["Gender"].value_counts())
# Out:
# Gender
# Male      771
# Female    729
# Name: count, dtype: int64

# %% [markdown]
# ## No.of males are more in the hospital

# %%
print(df["Hospital_Revenue"].sum())
# Out:
# 93796615.31

# %% [markdown]
# ## The total hospital revenue is 9.38 crores

# %%
d=pd.DataFrame(df.groupby("Diagnosis")["Length_of_Stay"].mean().sort_values(ascending=False))
d
# Out:
#                Length_of_Stay
# Diagnosis
# Infection            8.550000
# Migraine             8.163090
# Diabetes             8.082707
# Cancer               8.030888
# Fracture             7.696356
# Heart Disease        7.651064

# %% [markdown]
# ## Infection,migranine and diabetes diagnosis patients has high length of stay

# %%
e=df.groupby("City")["Patient_ID"].count().sort_values(ascending=False)
e
# Out:
# City
# Hyderabad    248
# Pune         216
# Bangalore    216
# Delhi        213
# Mumbai       213
# Ahmedabad    199
# Chennai      195
# Name: Patient_ID, dtype: int64

# %% [markdown]
# ## In Hyderabad city there are more patients

# %%
df.groupby("Doctor_Name")["Treatment_Cost"].sum().sort_values(ascending=False)
# Out:
# Doctor_Name
# Dr. Iyer      27330191.72
# Dr. Reddy     27235163.42
# Dr. Patel     26776046.22
# Dr. Mehta     25385947.18
# Dr. Khan      24640019.78
# Dr. Sharma    24236849.28
# Name: Treatment_Cost, dtype: float64

# %%
f=pd.DataFrame(df.groupby("Payment_Mode")["Treatment_Cost"].mean().sort_values(ascending=False))
f
# Out:
#               Treatment_Cost
# Payment_Mode
# UPI            108120.968722
# Card           106501.470202
# Insurance      101707.964462
# Cash            98418.024068

# %% [markdown]
# ## Through the UPI payment mode most of the transactions are happening.

# %%
df["Department"].value_counts()
# Out:
# Department
# Orthopedics         271
# Oncology            264
# Neurology           257
# General Medicine    242
# Pediatrics          242
# Cardiology          224
# Name: count, dtype: int64

# %% [markdown]
# # DATA VISUVALISATION

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(20,10))
plt.title("DASHBOARD")
plt.subplot(2,3,1)
sns.barplot(x="Diagnosis",y="Treatment_Cost",palette="viridis",data=a)
plt.subplot(2,3,2)
sns.lineplot(x="Department",y="Treatment_Cost",marker='o',color='black',data=b)
plt.subplot(2,3,3)
sns.countplot(x="Gender",data=df)
plt.subplot(2,3,4)
sns.barplot(x="Diagnosis",y="Length_of_Stay",color="lightgreen",data=d)
plt.subplot(2,3,5)
plt.pie(e.values,labels=e.index,autopct='%1d%%')
plt.subplot(2,3,6)
sns.lineplot(x="Payment_Mode",y="Treatment_Cost",color='green',marker='o',data=f)
plt.show()
# Out:
# C:\Users\GAYATHRI GOUTHAMI\AppData\Local\Temp\ipykernel_21396\2373052070.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Diagnosis",y="Treatment_Cost",palette="viridis",data=a)

# %% [markdown]
# # DATA STORY TELLING

# %% [markdown]
# ## 1.The average treatment cost is high in the heart disease diagnosis.
# ## 2.In the neurology department the treatment cost is high.
# ## 3.no.of male patients are more in the hospital.
# ## 4.Infection diagnosis patients has high length of stay in the hospital.
# ## 5.There are more patients from hyderabad city.
# ## 6.UPI payment mode is highly used for the payment of treatment cost.
